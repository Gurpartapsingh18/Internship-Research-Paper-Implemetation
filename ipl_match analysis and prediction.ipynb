# %%
import numpy  as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading the dataset

# %%
ipl_data = pd.read_csv('matches.csv')

# %%
ipl_data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl_data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [markdown]
# ## Analyzing the dataset and performing Exploratory Data Analysis

# %% [markdown]
# ## No. of seasons

# %%
ipl_data['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
#a=[]
#for i in ipl_data:
#    a.append(ipl_data['player_of_match'])

# %% [markdown]
# ## The top ten players with the most man of the match award

# %%
ipl_data['player_of_match'].value_counts()[0:20]
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# G Gambhir         13
# MS Dhoni          13
# AM Rahane         12
# MEK Hussey        12
# V Sehwag          11
# V Kohli           11
# DR Smith          11
# JH Kallis         10
# SR Watson         10
# SE Marsh           9
# A Mishra           9
# KA Pollard         9
# SR Tendulkar       8
# RV Uthappa         7
# Name: player_of_match, dtype: int64

# %%
ipl_data['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# G Gambhir         13
# MS Dhoni          13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=(8,5))
x= ipl_data['player_of_match'].value_counts()[0:5].keys()
y= ipl_data['player_of_match'].value_counts()[0:5]
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ipl_data['result'].value_counts()
# Out:
# normal       626
# tie            7
# no result      3
# Name: result, dtype: int64

# %%
ipl_data['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
ipl_data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#creating a new dataset with only the teams who have won batting first
batfirst_won = ipl_data[ipl_data['win_by_runs']!=0]

# %%
batfirst_won.head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # The histogram depicts that there were only a few games when the team batting first won by a large margin(>=120) in terms of the runs.

# %%
plt.figure(figsize=(5,7))
plt.hist(batfirst_won['win_by_runs'])
plt.xlabel("runs")
plt.ylabel("matches")
plt.show()

# %%
#the most no. of matches won by the team while batting first
batfirst_won["winner"].value_counts()[0:5]
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(list( batfirst_won["winner"].value_counts()[0:5].keys()) , list( batfirst_won["winner"].value_counts()[0:5]), color = ["skyblue" , "yellow" , "orange" , "green" , "red"])
plt.show()

# %%
batsecond_won = ipl_data[ipl_data["win_by_wickets"]!=0]

# %%
batsecond_won.head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %% [markdown]
# # team that won the match batting second

# %%
batsecond_won['winner'].value_counts()[0:10]
# Out:
# Kolkata Knight Riders          46
# Mumbai Indians                 44
# Royal Challengers Bangalore    42
# Delhi Daredevils               41
# Rajasthan Royals               38
# Kings XI Punjab                36
# Chennai Super Kings            33
# Sunrisers Hyderabad            18
# Gujarat Lions                  12
# Deccan Chargers                11
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(5,7))
plt.hist(batsecond_won['win_by_wickets'], bins = 30)
plt.xlabel("wickets")
plt.ylabel("matches")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(list( batsecond_won["winner"].value_counts()[0:5].keys()) , list( batsecond_won["winner"].value_counts()[0:5]) , color = ["skyblue" , "yellow" , "orange" , "green" , "red"])
plt.show()

# %%
ipl_data['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# ## The most played venues and stadium

# %%
warnings.simplefilter(action = 'ignore' , category = FutureWarning)
sns.set_style("darkgrid")
ls = ipl_data['venue'].value_counts().sort_values(ascending= False)
plt.figure(figsize=(15,8))
temp = sns.barplot(ls.index, ls.values , alpha = 0.8)
plt.title("Most Played Venue")
plt.xlabel('Stadiums' , fontsize = 15)
plt.ylabel('Matches' , fontsize = 15)
temp.set_xticklabels(rotation = 90 , labels = ls.index, fontsize = 17 )
plt.show()

# %% [markdown]
# ## Feroz Shah Kotla  was taken from the categorical variable to show which of the two batting or bowling it suited the most.

# %%
Delhi_stadium=ipl_data.loc[(ipl_data['venue']=='Feroz Shah Kotla') ]
Delhi_stadium_win_by_runs=Delhi_stadium[Delhi_stadium['win_by_runs']>0]
slices=[len(Delhi_stadium_win_by_runs),len(Delhi_stadium)-len(Delhi_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=20,shadow=1,explode=(0,0.2),autopct='%2.3f%%',colors=['#1519ef','#fc4811'])
plt.title('Feroz Shah Kotla')
plt.show()

# %%
# Best venue for defending your total
ipl_data.venue[ipl_data.win_by_runs!=0].mode()
# Out:
# 0    MA Chidambaram Stadium, Chepauk
# dtype: object

# %%
# Best venue to chase a total
ipl_data.venue[ipl_data.win_by_wickets!=0].mode()
# Out:
# 0             Eden Gardens
# 1    M Chinnaswamy Stadium
# dtype: object

# %%
# Best defending team
ipl_data.winner[ipl_data.win_by_runs!=0].mode()
# Out:
# 0    Mumbai Indians
# dtype: object

# %%
# Best chasing team
ipl_data.winner[ipl_data.win_by_wickets!=0].mode()
# Out:
# 0    Kolkata Knight Riders
# dtype: object

# %%
ipl_data['winner'].isnull().value_counts()
# Out:
# False    633
# True       3
# Name: winner, dtype: int64

# %% [markdown]
# ## Corelation matrix

# %%
corr_matrix = ipl_data.corr()
corr_matrix['winner'].sort_values(ascending=False)
# Out:
# winner            1.000000
# team2             0.454009
# team1             0.421931
# toss_winner       0.361034
# season            0.116276
# dl_applied        0.036798
# id                0.023235
# win_by_wickets    0.002463
# win_by_runs      -0.084207
# umpire3                NaN
# Name: winner, dtype: float64

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(ipl_data.corr(), annot = True)

# %%
ipl_data[ipl_data['winner'].isnull() ]
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# ...

# %%
#replacing the null values
ipl_data['winner'].fillna('draw' , inplace = True)

# %%
ipl_data['winner'].isnull().value_counts()
# Out:
# False    636
# Name: winner, dtype: int64

# %%
ipl_data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# draw                            3
# Name: winner, dtype: int64

# %%
team_encoding = { 
       'Mumbai Indians' :1,
        'Kolkata Knight Riders' : 2,
        'Royal Challengers Bangalore' : 3,
         'Deccan Chargers' : 4,
        'Chennai Super Kings' : 5,
       'Rajasthan Royals' : 6,
    'Delhi Daredevils' : 7,
    'Gujarat Lions' : 8,
    'Kings XI Punjab' : 9,
    'Sunrisers Hyderabad' : 10,
    'Rising Pune Supergiant'  : 11,
    'Rising Pune Supergiants' : 11,
    'Kochi Tuskers Kerala'     : 12,
    'Pune Warriors' : 13,
    'draw' : 14
    }

team_encode_dict = {
    'team1' : team_encoding,
    'team2' : team_encoding,
    'toss_winner' : team_encoding,
    'winner' : team_encoding
}

ipl_data.replace(team_encode_dict, inplace = True)

# %%
ipl_data.head(20)
# Out:
#     id  season       city        date  team1  team2  toss_winner  \
# 0    1    2017  Hyderabad  2017-04-05     10      3            3
# 1    2    2017       Pune  2017-04-06      1     11           11
# 2    3    2017     Rajkot  2017-04-07      8      2            2
# 3    4    2017     Indore  2017-04-08     11      9            9
# 4    5    2017  Bangalore  2017-04-08      3      7            3
# 5    6    2017  Hyderabad  2017-04-09      8     10           10
# 6    7    2017     Mumbai  2017-04-09      2      1            1
# 7    8    2017     Indore  2017-04-10      3      9            3
# 8    9    2017       Pune  2017-04-11      7     11           11
# 9   10    2017     Mumbai  2017-04-12     10      1            1
# 10  11    2017    Kolkata  2017-04-13      9      2            2
# 11  12    2017  Bangalore  2017-04-14      3      1            1
# 12  13    2017     Rajkot  2017-04-14     11      8            8
# ...

# %%
## misssing values in city column
ipl_data[ipl_data['city'].isnull() == True]
# Out:
#       id  season city        date  team1  team2  toss_winner toss_decision  \
# 461  462    2014  NaN  2014-04-19      1      3            3         field
# 462  463    2014  NaN  2014-04-19      2      7            2           bat
# 466  467    2014  NaN  2014-04-23      5      6            6         field
# 468  469    2014  NaN  2014-04-25     10      7           10           bat
# 469  470    2014  NaN  2014-04-25      1      5            1           bat
# 474  475    2014  NaN  2014-04-28      3      9            9         field
# 476  477    2014  NaN  2014-04-30     10      1            1         field
#
#      result  dl_applied  winner  win_by_runs  win_by_wickets player_of_match  \
# 461  normal           0       3            0               7        PA Patel
# 462  normal           0       7            0               4       JP Duminy
# 466  normal           0       5            7               0       RA Jadeja
# ...

# %%
ipl_data['city'].fillna('Dubai' , inplace = True)

# %%
ipl_data['city'].isnull().value_counts()
# Out:
# False    636
# Name: city, dtype: int64

# %%
ipl_data.describe()
# Out:
#                id       season       team1       team2  toss_winner  \
# count  636.000000   636.000000  636.000000  636.000000   636.000000
# mean   318.500000  2012.490566    5.540881    5.511006     5.371069
# std    183.741666     2.773026    3.329169    3.341677     3.293140
# min      1.000000  2008.000000    1.000000    1.000000     1.000000
# 25%    159.750000  2010.000000    3.000000    3.000000     2.000000
# 50%    318.500000  2012.000000    5.000000    5.000000     5.000000
# 75%    477.250000  2015.000000    9.000000    8.000000     7.250000
# max    636.000000  2017.000000   13.000000   13.000000    13.000000
#
#        dl_applied      winner  win_by_runs  win_by_wickets  umpire3
# count  636.000000  636.000000   636.000000      636.000000      0.0
# mean     0.025157    5.309748    13.682390        3.372642      NaN
# std      0.156726    3.288726    23.908877        3.420338      NaN
# min      0.000000    1.000000     0.000000        0.000000      NaN
# ...

# %%
ipl_data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# ## Dropping the redundant columns

# %%
ipl_data1 = ipl_data[['team1', 'team2', 'city' , 'toss_decision' , 'toss_winner' , 'venue' , 'winner']]

# %%
ipl_data1.shape
# Out:
# (636, 7)

# %%
from sklearn.preprocessing import LabelEncoder

ftr_list = ['city' , 'toss_decision' , 'venue']
encoder = LabelEncoder()
for ftr in ftr_list:
    ipl_data1[ftr] = encoder.fit_transform(ipl_data1[ftr])
    print(encoder.classes_)
    
ipl_data1
# Out:
# ['Abu Dhabi' 'Ahmedabad' 'Bangalore' 'Bloemfontein' 'Cape Town'
#  'Centurion' 'Chandigarh' 'Chennai' 'Cuttack' 'Delhi' 'Dharamsala' 'Dubai'
#  'Durban' 'East London' 'Hyderabad' 'Indore' 'Jaipur' 'Johannesburg'
#  'Kanpur' 'Kimberley' 'Kochi' 'Kolkata' 'Mumbai' 'Nagpur' 'Port Elizabeth'
#  'Pune' 'Raipur' 'Rajkot' 'Ranchi' 'Sharjah' 'Visakhapatnam']
# ['bat' 'field']
# ['Barabati Stadium' 'Brabourne Stadium' 'Buffalo Park'
#  'De Beers Diamond Oval' 'Dr DY Patil Sports Academy'
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'
#  'Dubai International Cricket Stadium' 'Eden Gardens' 'Feroz Shah Kotla'
#  'Green Park' 'Himachal Pradesh Cricket Association Stadium'
#  'Holkar Cricket Stadium' 'JSCA International Stadium Complex' 'Kingsmead'
#  'M Chinnaswamy Stadium' 'MA Chidambaram Stadium, Chepauk'
#  'Maharashtra Cricket Association Stadium' 'Nehru Stadium'
#  'New Wanderers Stadium' 'Newlands' 'OUTsurance Oval'
#  'Punjab Cricket Association IS Bindra Stadium, Mohali'
# ...

# %%
from sklearn.model_selection import train_test_split

train_df , test_df = train_test_split(ipl_data1, test_size = 0.2 , random_state=5)
print(train_df.shape)
print(test_df.shape)
# Out:
# (508, 7)
# (128, 7)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

def print_model_scores(model, data, predictor, target):
    model.fit(data[predictor] , data[target])
    predictions = model.predict(data[predictor])
    accuracy = accuracy_score(predictions, data[target])
    print('Accuracy : %s' % '{0:.2}'.format(accuracy) )
    scores = cross_val_score(model, data[predictor], data[target], scoring = 'neg_mean_squared_error',cv=5)
    print('cv scores : {}' .format(np.sqrt(-scores)))
    print(f'Average RMSE : {np.sqrt(-scores).mean()}')

# %%
target_var = ['winner']
predictor_var = {'team1' , 'team2', 'venue' , 'toss_winner' , 'city' , 'toss_decision' }
model= LogisticRegression()

print_model_scores(model, train_df , predictor_var , target_var)
# Out:
# Accuracy : 0.31
# cv scores : [3.00163354 3.50629686 2.71885212 3.46410162 3.45838055]
# Average RMSE : 3.2298529375681624

# %%
model = RandomForestClassifier(n_estimators = 100)
print_model_scores(model, train_df , predictor_var , target_var)
# Out:
# Accuracy : 0.91
# cv scores : [2.81452814 3.49088449 3.34018903 3.22275327 3.15757772]
# Average RMSE : 3.205186526793562

# %%
pd.Series(index = predictor_var, data = model.feature_importances_)
# Out:
# team1            0.220626
# venue            0.165334
# team2            0.251013
# toss_decision    0.037126
# toss_winner      0.174237
# city             0.151664
# dtype: float64

# %% [markdown]
# ## Testing the data

# %%
print_model_scores(model, test_df , predictor_var , target_var)
# Out:
# Accuracy : 0.95
# cv scores : [3.78255103 3.16227766 2.82842712 3.78945906 2.96647939]
# Average RMSE : 3.305838855157762
